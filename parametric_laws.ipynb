# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.preprocessing import PowerTransformer

# %%
# Générer des données exponentielles
np.random.seed(42)
data = np.random.exponential(scale=2, size=1000)

plt.figure(figsize=(12, 6))

# Histogramme des données initiales
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title("Distribution avant transformation")
plt.xlabel("Valeurs")
plt.ylabel("Fréquence")
# Out:
# Text(0, 0.5, 'Fréquence')

# %%
# Appliquer la transformation Box-Cox (PowerTransformer avec méthode 'box-cox')
pt = PowerTransformer(method='box-cox')
data_boxcox = pt.fit_transform(data.reshape(-1, 1)).flatten()

# %%
plt.subplot(1, 2, 2)
plt.hist(data_boxcox, bins=30, color='lightcoral', edgecolor='black')
plt.title("Distribution après Box-Cox")
plt.xlabel("Valeurs")
plt.ylabel("Fréquence")

plt.tight_layout()
plt.show()

# %%
# Vérification de la normalité avec le test de Shapiro-Wilk
stat_before, p_before = stats.shapiro(data)
stat_after, p_after = stats.shapiro(data_boxcox)

print(f"Test de Shapiro-Wilk avant transformation : p-value = {p_before:.4f}")
print(f"Test de Shapiro-Wilk après transformation : p-value = {p_after:.4f}")
# Out:
# Test de Shapiro-Wilk avant transformation : p-value = 0.0000
# Test de Shapiro-Wilk après transformation : p-value = 0.0037
